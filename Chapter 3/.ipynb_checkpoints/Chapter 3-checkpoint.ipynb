# %% [markdown]
# # Chapter 3: Reaction Kinetic Models in Reactor Design
#
# In the intricate world of chemical engineering and reactor design, understanding the kinetics of chemical reactions is the key to unlocking the potential of countless industrial processes. In Chapter 3 of our reactor design textbook, aptly titled "Reaction Kinetic Models in Reactor Design," we embark on a comprehensive exploration of this critical subject, covering a range of essential elements that will shape your understanding of reaction kinetics.
#
# 1. Definition of Reaction Rates: Before delving into the intricacies of reaction kinetics, we start by establishing a clear understanding of reaction rates. You will learn how to quantify the speed at which chemical reactions occur and the factors that influence these rates. This fundamental knowledge lays the groundwork for our exploration of reaction kinetics.
#
# 2. Law of Mass Action: Building on our understanding of reaction rates, we move on to explore the Law of Mass Action. We will unravel how this fundamental principle governs reaction rates by expressing them in terms of reactant concentrations. You will discover how this principle underlies the mathematics of chemical kinetics, providing a solid framework for understanding and predicting reaction rates.
#
# 3. Effect of Temperature on the Reaction Rate Constant (Arrhenius): Temperature plays a pivotal role in reaction kinetics, and the Arrhenius equation is our compass in navigating this aspect. We will delve into how temperature influences the rate constants of reactions, exploring the Arrhenius equation and its significance. This knowledge will empower you to optimize reaction conditions for maximum efficiency and yield.
#
# 4. Autocatalytic Reactions: Some reactions have the remarkable ability to catalyze themselves as they progress. Autocatalytic reactions will be demystified in this chapter, and you will learn how to identify and design reactors for such systems. We will uncover the unique dynamics and challenges posed by autocatalysis in chemical processes.
#
# 5. Reversible Reactions: In many real-world scenarios, reactions are not one-directional; they can proceed in both the forward and reverse directions. Chapter 3 provides you with the tools to analyze and design reactors for reversible reactions, taking into account equilibrium constants and reaction directionality.
#
# 6. Multiple Reaction Systems: Complex chemical processes often involve multiple reactions occurring simultaneously. This chapter equips you with the knowledge and techniques to dissect and analyze these intricate systems. You will learn to design reactors that account for the interplay between multiple reactions, enabling you to control product distributions and optimize reactor performance.
#
# Throughout this chapter, real-world examples and practical applications will illustrate the concepts discussed. You will gain the skills necessary to select appropriate kinetic models, predict reaction rates, and make informed decisions in reactor design. By the chapter's conclusion, you will be well-prepared to tackle the multifaceted challenges of reactor design in diverse industries, armed with a deep understanding of reaction rates, the law of mass action, Arrhenius kinetics, autocatalytic reactions, reversible reactions, and multiple reaction systems.
#
# So, let us embark on this enlightening journey into the world of reaction kinetic models, where we unravel the secrets to designing reactors that drive progress, innovation, and sustainability in chemical engineering.

# %% [markdown]
# ## 1. DEFINITION OF REACTION RATES:
#
# Reaction rates are a fundamental concept in chemistry that describes how quickly a chemical reaction takes place. In every chemical reaction, reactants undergo a transformation to form products. The rate of a reaction quantifies the speed at which these reactants are consumed and products are formed.
#
# The rate of a reaction is influenced by several factors, including the concentration of reactants, temperature, pressure (for gas-phase reactions), and the presence of catalysts. Higher concentrations of reactants generally lead to faster reactions, as more collisions between particles occur, increasing the likelihood of successful reactions. Similarly, an increase in temperature usually accelerates the reaction rate since particles have more kinetic energy, resulting in more frequent and energetic collisions.
#
# The rate equation of a reaction is an expression that mathematically represents the relationship between the rate of the reaction and the concentrations of the reactants. Different reactions exhibit different rate laws, which can be determined through experimental measurements.
#
# Understanding reaction rates is crucial in various fields, such as chemical engineering, pharmaceutical development, environmental studies, and many other industrial applications. By studying and controlling reaction rates, scientists and engineers can optimize processes, design efficient reactions, and produce desired products with high yields.
#
# Overall, the study of reaction rates provides valuable insights into the dynamics of chemical reactions, helping us comprehend the intricacies of the natural world and enabling us to manipulate chemical processes for practical purposes.
#
# ## Different rates of reaction
#
# ### Rate of reaction *j* ($r_j$)
#
# The $r_j$ [(Link do definition by IUPAC)](https://goldbook.iupac.org/terms/view/R05156) is basically the speed at which a chemical reaction *j* takes place and quantifies how quickly reactants are converted into products during a chemical reaction **per unit volume**. The definition is defined with respect to the stoichiometric number (or stoichiometric coefficient as per ) - $\nu_{ij}$.
#
# ### Rate of reaction of component *i* in reaction *j* ($r_{ij}$)
#
# The $r_{ij}$ can be defined as the rate at which component *i* reacts in reaction *j* - $r_{ij}$ tends to be described by the [Law of mass action](https://www.britannica.com/science/law-of-mass-action) and will differ for the different reactions (*j*) in the system. This will be addressed in more detail later in the course.
#
# ### Rate of reaction of component *i* ($r_{i}$)
#
# The $r_i$ can be defined as the total reaction rate of component *i* in the system (as used in the general mole balance equations) and can be mathematically described by:
#
# $$ r_i = \sum_j(r_{ij})$$
#
# ### Relating $r_j$, $r_{ij}$, and $r_i$
#
# In a batch reactor under constant volume conditions*</u> for the generic reaction *j* with the form
#
# $$aA + bB ... \to pP +qQ... $$
#
# $r_j$ [can be defined as](https://goldbook.iupac.org/terms/view/R05156)
#
# $$ r_j = \frac{dC_{Aj}}{dt}\frac{1}{-a_j} = \frac{dC_{Bj}}{dt}\frac{1}{-b_j}  = \frac{dC_{Pj}}{dt}\frac{1}{p_j} = \frac{dC_{Qj}}{dt}\frac{1}{q_j} $$
#
# Now since $$\frac{dC_A}{dt} = \frac{dN_A}{dt}\frac{1}{V} = r_{i}$$ for a constant volume batch reactor it can be deduced that:
# $$\frac{dC_{Aj}}{dt} = \frac{dN_{Aj}}{dt}\frac{1}{V} = r_{ij}$$
# since
# $$\frac{dN_A}{dt}\frac{1}{V} = \sum_j{\frac{dN_{Aj}}{dt}\frac{1}{V}}$$
#
# and therefore:
#
# $$ r_{ij} = r_{j}\nu_{ij} $$
#
# and
#
# $$ r_i = \sum_jr_{j}\nu_{ij} $$
#
# This means that a vector of component rates ($\bar{r_i}$) can be defined using a dot multiplication of a matrix of stoichmetric coefficients ($\nu_{ij}$) and a vector of reaction rates ($\bar{r_j}$):
#
# $$\bar{r_i} = \bar{r_j}\cdot \nu_{ij}  $$

# %% [markdown]
# ## 2. LAW OF MASS ACTION: RATE AND CONCENTRATION
#
# In the realm of chemical kinetics, few principles hold as much significance as the Law of Mass Action. It is a foundational concept that forms the bedrock upon which our understanding of reaction rates is built. In this section, "Law of Mass Action: Rate and Concentration," we will embark on a journey to unravel the intricate relationship between the rate of a chemical reaction and the concentrations of its reactants. This relationship, succinctly encapsulated in the Law of Mass Action, is at the heart of our ability to predict, control, and optimize chemical reactions within various industrial processes.
#
# The Law of Mass Action provides us with a profound insight into how the concentrations of reactants influence the speed at which a chemical reaction proceeds. By examining this relationship, we gain the power to tailor reactions to our desired outcomes, whether it be to accelerate production, maximize yield, or minimize byproducts.
#
# Throughout this section, we will explore the principles of the Law of Mass Action in detail. We will learn how to express reaction rates as mathematical functions of reactant concentrations, demystifying the science behind chemical kinetics. By the end, you will not only grasp the fundamental concepts but also appreciate how this understanding becomes an indispensable tool in the design and optimization of chemical reactors.
#
# So, as we delve into the intricacies of the Law of Mass Action, let us equip ourselves with the knowledge and insights that will enable us to master the art of predicting and controlling reaction rates based on reactant concentrations, a skill that lies at the core of chemical engineering and reactor design.

# %% [markdown]
# ### Law of Mass Action:
#
# Take a homogeneous reaction:
# $$ A+B\to C$$
#
# One can imagine that the amount of C formed is related to the amount of molecular collisions between A and B. Statistically one can prove that the likelihood of a collision is directly proportional to the molecular density (concentration) of both A and B. For this ideal situation it can be shown that
#
# $$ r = kC_AC_B $$
#
# Note that the product concentration only influence the rate indirectly due to the decrease in reactant concentration.
#
# To incorporate for non-idealities and catalysed reactions, reaction engineers typically generalise the rate-concentration relationship to a generic power law model giving:
#
# $$ r = kC_A^mC_B^n $$
#
# ### Elementary Reactions:
#
# Sometimes (and only sometimes) it happens that the following reaction:
# $$aA+bB\to cC$$
#
# has a rate expression given by:
#
# $$r = kC_A^aC_B^b$$
#
# This is referred to as an *elementary reaction*. **Note that there is no need for the rate order to be related to the reaction stoichiometry.**
#
# <u>Example:</u>
# $$ 2A+3B\to 4C $$
#
# $$ r = k_AC_AC_AC_BC_BC_B = k_AC_A^2C_B^3 $$
#
# ### However: Not all chemical reactions are elementary,
#
# and the reasons for this variability lie in the complexity of molecular interactions and the way reactions occur at the molecular level. Here are several key reasons why not all reactions are elementary:
#
# 1. Complexity of Molecular Interactions: In an elementary reaction, reactant molecules directly collide and transform into products in a single step. However, many reactions involve multiple steps and intermediate species formed during the reaction process. These intermediate species can have their own distinct reactivity and stability, leading to a sequence of elementary steps rather than a single, straightforward reaction.
#
# 2. Molecular Structure: The structure of reactant molecules plays a crucial role in determining reaction mechanisms. Some molecules are inherently more stable or less reactive, leading to the need for multiple steps to transform them into products. Additionally, the spatial orientation of reactants can influence reaction pathways, and certain orientations may lead to complex mechanisms.
#
# 3. Activation Energy: Reactions often require an energy input to overcome an energy barrier called the activation energy. In elementary reactions, this barrier is relatively low and can be easily surmounted by the reactants' kinetic energy. However, in non-elementary reactions, the activation energy may be significantly higher, necessitating additional steps or intermediates to reach the transition state.
#
# 4. Reaction Conditions: The conditions under which a reaction occurs, such as temperature, pressure, and the presence of catalysts, can influence the reaction mechanism. Different conditions may favor different reaction pathways, leading to non-elementary reactions.
#
# 5. Reaction Kinetics: Observing a reaction at the macroscopic level may not reveal the underlying molecular-level mechanisms. Non-elementary reactions may appear as single-step reactions when studied under certain conditions or at high concentrations, but detailed kinetic studies and mechanistic investigations can reveal the true complexity of the reaction.
#
# 6. Quantum Mechanics: Quantum mechanical calculations have shown that even seemingly simple reactions can involve complex molecular rearrangements at the atomic level. These quantum effects can result in non-elementary behavior.
#
# 7. Isomerization and Tautomeric Equilibria: Some reactions involve the conversion of one isomer or tautomeric form to another, which can be a multi-step process due to the rearrangement of atoms or electrons within the molecule.
#
# In summary, the complexity of molecular interactions, molecular structure, activation energy barriers, reaction conditions, and quantum effects can all contribute to the non-elementary nature of many chemical reactions. Understanding these complexities and elucidating reaction mechanisms is a central focus of chemical kinetics and mechanistic chemistry.
#
# ### Note on powers and units:
# The order of the reaction is typically whole numbers, but can be fractions.
#
# Power law kinetics do not always represent reaction rates, but for most reactions the power law format is sufficient.
#
# It is very important to realise that the rate constant has units that is related to the rate definition (volume or mass) as well as the overall rate order. The units of the constant therefore contains information!
#
# $$ r = kC_AC_B^2\: [r_A\: units\: \frac{kmol}{m^3.min}] $$
#
# $$ Units \:of\: k = \frac{m^6}{kmol^2.min}$$
#
# $$ r' = k'C_AC_B^2\: [r_A\: units\: \frac{kmol}{kg\:cat.min}] $$
#
# $$ Units\: of\: k' = \frac{m^9}{kmol^2.min.kg\:cat}$$

# %% [markdown]
# ## FITTING EXPERIMENTAL DATA WITH PYTHON
#
# We start by graphically representing the experimental data:
#
# ![ExpData.png](data:image/png;base64,...)
#
# We now need a ‘theoretical’ line that will resemble or ‘fit’ the experimental data
#
# ![ExpDataFit1.png](data:image/png;base64,...)![ExpDataFit2.png](data:image/png;base64,...)
#
#
# We obtain an expression for the blue line by proposing a rate expression, followed by substituting the rate expression into a **mole balance(s)**. The resulting equation(s) need to be solved for a choice of rate constant and rate order(s)
#
# **REMEMBER:**
#
# **k is used to fit the magnitude of the experimental curve (values measured)**
#
# **m, n are used to fit the *SHAPE* of the curve**

# %% [markdown]
# # Example
#
# $$ A+3B\to 4C $$
#
# Liquid phase, spontaneous
#
# Raw data:
#
# |Time (min)| $C_A$ (mol/L)|
# |---|---|
# |0|2.00|
# |2|1.33|
# |4|1.08|
# |6|0.89|
# |9|0.69|
# |12|0.59|
# |16|0.55|
# |19|0.48|
#
# $C_{Bo} = 5 mol/L$

# %%
from scipy.integrate import odeint
from numpy import linspace
from ipywidgets import interact
import matplotlib.pyplot as plt
# %matplotlib inline

V = 1 #L chosen base
CAo = 2 #mol/L
NAo = CAo*V
CBo = 5 #mol/L
NBo = CBo*V
CCo = 0
NCo = CCo*V

te = 0, 2, 4, 6, 9, 12, 16, 19
CAe = 2.00, 1.33, 1.08, 0.89, 0.69, 0.59, 0.55, 0.48

tspan = linspace(0, 20, 100)

def func(k = .01, m = 1, n = 3):
    
    def ri(N):
        NA, NB, NC = N
        CA, CB, CC = N/V
        rA = -k*CA**m*CB**n
        rB = 3*rA
        rC = -4*rA
        return [rA, rB, rC]

    def diffs(N, t):
        NA, NB, NC = N
        rA, rB, rC = ri(N)
        dNAdt, dNBdt, dNCdt = ri(N)*V
        return [dNAdt, dNBdt, dNCdt]
    
    N = odeint(diffs, [NAo, NBo, NCo], tspan)
    C = N/V
    CA = C[:, 0]
    CB = C[:, 1]
    CC = C[:, 2]
    plt.plot(te, CAe, 'o', tspan, CA)

interact(func, k = (0, 0.1, 0.0001), m = (0, 3, 1), n = (0, 3, 1))
# Out:
# interactive(children=(FloatSlider(value=0.01, description='k', max=0.1, step=0.0001), IntSlider(value=1, descr…
# <function __main__.func(k=0.01, m=1, n=3)>

# %% [markdown]
# ## 3. RATE AND TEMPERATURE
#
# Reaction orders do not vary with temperature, only the reaction rate constant. This is due to the increase in molecular motion (more collisions). We use the Arrhenius relationship to represent this:
#
# $$k = k_oe^{-\left(\frac{E_A}{RT}\right)} $$
# $$ ln k = ln k_o + \frac{-E_A}{RT} $$
#
# We need the two parameters E and ko (both positive). T is defined as the Kelvin temperature and R is the universal gas constant
#
# Plotting this function over the complete temperature range gives:
#
# ![kvsT.png](data:image/png;base64,...)
#
# For reactor applications we have an exponential-like behaviour. Note that ko is the rate constant at infinite high temperatures.
#
# Make sure you realise that :
# $$ -\left(\frac{E_A}{RT}\right) $$
# This should be a dimensionless group, thus get your units right!

# %% [markdown]
# Activation Energy (E) has units of J/mol. This parameter quantifies the amount of energy required to increase the reaction rate constant.  of rate constant increase with increasing temperature. Note that Arhenius implies that HOTTER IS ALWAYS FASTER, and that the activation energy tells us how much faster.
#
# See for yourself in the following figure:

# %%
from numpy import linspace, exp
from ipywidgets import interact
import matplotlib.pyplot as plt

R = 8.314 #J/mol.K

def kT(ko1 = 2e7, ko2 = 2e7,  EA1 = 50000, EA2 = 50000,
       Tmin = 273.15, Tmax = 1000):
    T = linspace(Tmin, Tmax, 1000)
    k1 = ko1*exp(-EA1/(R*T))
    k2 = ko2*exp(-EA2/(R*T))
    plt.plot(T, k1, T, k2)
    plt.legend(['k1', 'k2'], loc=2)
    plt.ylabel('k (1/s)')
    plt.xlabel('T (K)')
    
interact(kT, ko1=(1e6, 1e9, 1e5), ko2=(1e6, 1e9, 1e5),
         EA1=(10000, 100000, 1000), EA2=(10000, 100000, 1000),
         Tmin=(150, 1000, 10), Tmax=(1000, 1000, 10))
# Out:
# interactive(children=(FloatSlider(value=20000000.0, description='ko1', max=1000000000.0, min=1000000.0, step=1…
# <function __main__.kT>

# %%
from numpy import linspace, exp, log
from ipywidgets import interact
import matplotlib.pyplot as plt

R = 8.314 #J/mol.K

def kT(ko1 = 2e7, ko2 = 2e7,  EA1 = 50000, EA2 = 50000,
       Tmin = 273.15, Tmax = 1000):
    T = linspace(Tmin, Tmax, 1000)
    logk1 = log(ko1*exp(-EA1/(R*T)))
    logk2 = log(ko2*exp(-EA2/(R*T)))
    plt.plot(1/T, logk1, 1/T, logk2)
    plt.legend(['ln k1', 'ln k2'])
    
interact(kT, ko1=(1e5, 1e9, 1e5), ko2=(1e5, 1e9, 1e5),
         EA1=(10000, 100000, 1000), EA2=(10000, 100000, 1000),
         Tmin=(150, 300, 10), Tmax=(300, 100000, 10))
# Out:
# interactive(children=(FloatSlider(value=20000000.0, description='ko1', max=1000000000.0, min=100000.0, step=10…
# <function __main__.kT>

# %% [markdown]
# # Example
#
# Example 3-1 (textbook):
#
# Calculate the activation energy for the decomposition of benzene diazonium chloride to give chlorobenzene and nitrogen using the following information for this first-order reaction:
#
# |k(1/s)|0.00043|0.00103|0.00180|0.00355|0.00717|
# |---|---|---|---|---|---|
# |T(K)|313.0|319.0|323.0|328.0|333.0|

# %% [markdown]
# Find the ln(k) and 1/T values and plot:

# %%
from numpy import log, array, exp, linspace
from scipy.stats import linregress 
import matplotlib.pyplot as plt
# %matplotlib inline

k = array([0.00043, 0.00103, 0.00180, 0.00355, 0.00717])
 
T = array([313, 319, 323, 328, 333])

lnk = log(k)

slope, intercept, r_value, p_value, std_err = linregress(1/T, lnk)

ko = exp(intercept)
EA = -slope*8.314
print('ko=', ko, '1/s,', 'EA=', EA, 'J/mol,', 'r^2=', r_value**2)

Tspan = linspace(313, 333)
k = ko*exp(-EA/(8.314*Tspan))

plt.plot(1/T, lnk, 'o', 1/Tspan, log(k))
plt.legend(['Experimental points', 'Model'])
# Out:
# ko= 8.030276391880205e+16 1/s, EA= 121481.50941813667 J/mol, r^2= 0.9998570770329075

# %%
from numpy import log, array, exp, linspace, array
from scipy.stats import linregress 
import matplotlib.pyplot as plt
# %matplotlib inline

k = array([0.00043, 0.0036, 0.0072])
T = array([313, 328, 333])

lnk = log(k)

slope, intercept, r_value, p_value, std_err = linregress(1/T, lnk)

ko = exp(intercept)
EA = -slope*8.314
print('ko=', ko, '1/s,', 'EA=', EA, 'J/mol,', 'r^2=', r_value**2)

Tspan = linspace(313, 333)
k = ko*exp(-EA/(8.314*Tspan))

plt.plot(1/T, lnk, 'o', 1/Tspan, log(k))
plt.legend(['Experimental points', 'Model'])

kpred = ko*exp(-EA/(8.314*array([313, 319, 323, 328, 333])))
print(kpred)
# Out:
# ko= 9.147728419212114e+16 1/s, EA= 121811.86274770713 J/mol, r^2= 0.9999383896690198
# [0.00042869 0.00103399 0.00182614 0.00364616 0.00713049]

# %%
k = array([0.00043, 0.00103, 0.00180, 0.00355, 0.00717])
plt.plot(k, kpred, 'o')

# %%
from numpy import array
import matplotlib.pyplot as plt
# %matplotlib inline

te = array([0, 2, 4, 6, 9, 12, 16, 19])
CAe = array([2, 1.33, 1.08, 0.89, 0.69, 0.59, 0.55, 0.48])

plt.plot(te, CAe, 'o')

# %% [markdown]
# We need differential equations (DE’s) that describe the change of $C_A$, $C_B$ (and $C_C$). Since all the concentrations are related by stoichiometry we only need to describe one concentration (since the others will be functions of this concentration). But the fastest method is to describe each reactant concentration in its own DE. We therefore need to do an A and B mole balance
#
# $$ \frac{dN_i}{dt} = r_iV $$
#
# $$ r_A = -kC_A^mC_B^n $$
#
# $$ r_B = 3r_A $$
#
# $$r_C = -4r_A $$

# %% [markdown]
# ## 4. AUTOCATALYTIC REACTIONS
#
# Look at this interesting irreversible reaction:
#
# $$A+B \to 2B$$
#
# A molecule B reacts with its isomer A (same molecular weight) to form two of itself. There need to be isomers as well as product present for the reaction to happen. The rate will typically be given by:
#
# $$r_A=-kC_A^nC_B^m$$
#
# One will typically start with lots of A and small amounts of B. A will get less and B will get more. What will happen to the rate?
#
# Let’s say $C_A+C_B=10$ and n=m=1. What combination of $C_A$ and $C_B$ will give the maximum product (rate) in a constant volume batch reactor?
#
# $$\frac{dC_B}{dt} = r_B$$
#
#
# The above calculation should make the following graph clear:
#
# ![Autocatalytic.png](data:image/png;base64,...)
#
#
# Since the rate goes through a maximum, the slope of CB should also:
# ![Autocatalytic 2.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Multiple Reactions
#
# Most reactions do not occur in isolation, but rather simultaneously with other reactions. For these reactions selectivity (relative ratios of components) becomes important. Take the simple reactions occurring simultaneously:
#
# E.g.
# Reaction 1:
# $$A\to B$$
#
# Reaction 2:
# $$A\to2C$$
#
# If we assume power law behaviour, the rates of reaction for the respective species can be described as the sum of the reaction rates of the specific species in each reaction:
#
# $$r_{A_1} = -k_{A_1}C_A^{m_1}$$
# $$r_{A_2} = -k_{A_2}C_A^{m_2}$$
# $$r_A = r_{A_1}+r_{A_2}$$
#
# $$r_{B_1} = -r_{A_1}$$
# $$r_{B_2} = 0$$
# $$r_B = r_{B_1}+r_{B_2}$$
#
# $$r_{C_1} = 0$$
# $$r_{C_2} = -2r_{A_2}$$
# $$r_C = r_{C_1}+r_{C_2}$$
#
# Using the rate expressions the mole balances for any reactor configuration can be solved:
# Batch:
# $$\frac{dN_i}{dt} = r_iV$$
#
# PFR:
# $$\frac{dF_i}{dV} = r_i$$
#
# CSTR:
# $$F_{Ao}-F_A = -r_AV$$
#
# To solve this in PYTHON is easy. It is however not possible to reduce the description to one DE, neither can we use conversion or stoicheometric tables any more. Take note of this.
#
# Tip: A typical question for this reaction scheme will entail maximizing the ratio of B to C using temperature. The difference in activation energies will be crucial.

# %% [markdown]
# ## REACTIONS IN SERIES
#
# Take the reaction scheme:
# $$ A\to B\to C $$
#
# This reaction scheme can be seen as multiple reactions:
#
# Reaction 1:
# $$A\to B$$
#
# Reaction 2:
# $$B\to C$$
#
# Which means the same method as above can be used to describe the reaction rates:
#
# $$r_{A_1} = -k_{A_1}C_A^{m_1}$$
# $$r_{A_2} = 0$$
# $$r_A = r_{A_1}+r_{A_2}$$
#
# $$r_{B_1} = -r_{A_1}$$
# $$r_{B_2} = -k_{B_2}C_B^{n_2}$$
# $$r_B = r_{B_1}+r_{B_2}$$
#
# $$r_{C_1} = 0$$
# $$r_{C_2} = -r_{B_2}$$
# $$r_C = r_{C_1}+r_{C_2}$$
#
# Using this in multiple mole balances, followed by numerical solving gives:
#
# ![Multiple reactions.png](data:image/png;base64,...)
#
#
# Note that $C_B$ goes through a maximum, thus $r_C$ also goes through a maximum and therefore the inflection on the $C_C$ curve.

# %% [markdown]
# ## MULTIPLE REACTIONS IN GENERAL
#
# Take the reaction scheme:
#
# $$3A\to B+C$$
# $$2C+A\to 3D $$
# $$ 4D+3C\to 3E $$
#
# If it is known that the kinetics of the system can be described by:
#
# $$ r_1 = k_{1}C_A $$
# $$ r_2 = k_{2}C_C^2C_A $$
# $$ r_3 = k_{3}C_CC_D $$
#
# Determine $r_A$, $r_B$, $r_C$, $r_D$, $r_E$
#
# The net rate expression for a component (from different reactions) is used in the mole balance. Make sure to check the reference specie of the rate constants.
#
# You can know model any complex reaction system for a given set of kinetics. Even the magical B-Z reaction (look it up)

# %% [markdown]
# # Solution
#
# $$ r_{A_1} = -k_{A_1}C_A $$
# $$ r_{B_1} = -\frac{1}{3} r_{A_1} $$
# $$ r_{C_1} = -\frac{1}{3} r_{A_1} $$
# $$ r_{D_1} = 0$$
# $$ r_{E_1} = 0$$
# \
# $$ r_{A_2} = -\frac{1}{3} r_{D_2} $$
# $$ r_{B_2} = 0$$
# $$ r_{C_2} = -\frac{2}{3} r_{D_2} $$
# $$ r_{D_2} = k_{D_2}C_C^2C_A $$
# $$ r_{E_2} = 0$$
# \
# $$ r_{A_3} = 0$$
# $$ r_{B_3} = 0$$
# $$ r_{C_3} = -\frac{3}{3} r_{E_3} $$
# $$ r_{D_3} = -\frac{4}{3} r_{E_3} $$
# $$ r_{E_3} = k_{E_3}C_CC_D $$
# \
# $$ r_i = \sum r_{i_j} $$
# $$i = A, B, C, D, E $$
# $$j = 1, 2, 3$$

# %% [markdown]
# ## Reversible reactions
#
# From the example of the 4-year old and the 6-year old playing on the tennis court you should understand that:
# ![Reversible reactions.png](data:image/png;base64,...)
#
#
# - At a certain time the net-amount of balls on a side will remain the same
# - This implies that the rate of balls added to a side is the same as that of the balls leaving the side
# - The rate of throwing balls over the net is related to the amount of balls on a side
# - Plotting the amount off balls on a side against time will always result in a smooth profile.
#
# A reversible reaction behaves very similar!

# %% [markdown]
# Take the following reaction:
#
# $$ A \leftrightharpoons B$$
#
# Which can be seen as two reactions:
#
# $$ A \to B$$
#
# $$ B \to A$$
#
# Using an elementary assumption (all reactions in this section will be elementary) we get:
#
#
#
# $$ r_A = -k_{A1}C_A+k_{A2}C_B $$
#
# At equilibrium the forward rate is the same as the reverse rate:
#
# $$ r_A =-k_{A1}C_A+k_{A2}C_B = 0 $$
#
# Resulting in the following equality:
#
# $$ \frac{C_{Be}}{C_{Ae}} = \frac{k_{A1}}{k_{A2}} = K_C $$
#
# Make sure you know the definition of the equilibrium constant! The rate can now also be expressed as:
#
# $$ r_A = -k_{A1}C_A+\frac{k_{A1}}{K_C}C_B$$
#
# Depending on the initial amount of A and B we will get different profiles, always ending at a constant ratio of concentrations
#
# $$ C_{Ao}+C_{Bo}= constant $$
# ![Equilibrium1.png](data:image/png;base64,...)
#
# ![Equilibrium2.png](data:image/png;base64,...)
#
# If we use conversions, will negative conversions be possible? Think of a example.
#
# Depending on the initial amount of A and B we will get different profiles, always ending at a constant ratio of concentrations

# %% [markdown]
# ### Fitting reversible reactions
#
# In CKN320 we will only consider elementary reversible reactions.  This entails a simple relationship between the rate constants for any reaction:
#
# $$ \frac{k_{A1}}{k_{A2}}= K_C$$
#
# In order to fit experimental data we require the equilibrium concentrations to calculate Kc. Note that according to definitions the powers used in Kc is the same as the stoicheometric coefficients:
#
# $$ aA+bB\rightleftharpoons cC $$
#
# $$K_C = \frac{C_C^c}{C_A^a C_B^b}$$
#
# ![Fit reversible.png](data:image/png;base64,...)
#
# Once $K_c$ is known we only need to fit one rate parameter ($k_1$). The model should end at the final equilibrium concentration. If not $K_c$ was not calculated correctly.
#
# ![Fit reversible 2.png](data:image/png;base64,...)

# %% [markdown]
# ### EQUILIBRIUM AND TEMPERATURE
#
# $K_c$ is a function of temperature and Van't Hoff’s equation is used to determine $K_c$ as a function of temperature:
#
# $$ K_C = K_{Co}e^{\frac{-\Delta H}{RT}} $$
#
# The expression looks very similar to the Arrhenius equation.
#
# **HAND-IN**
#
# Prove that the Van't Hoff equation can be derived from the Arrhenius equation
#
# The major difference is that $\Delta H$ can be positive (endothermic) or negative (exothermic). $\Delta H$ is normally a constant for a reaction.
#
# ![Vant hoff endo.png](data:image/png;base64,...)
#
# ![Vant hoff exo.png](data:image/png;base64,...)
#
#
# Normally $K_c$ is known at a temperature. The van't Hoff equation is then used to find $K_c$ at a different temperature. We can either calculate Kco or use a difference relationship to determine the new $K_c$:
#
# $$ \ln{\left(\frac{K_{c1}}{K_{c2}}\right)} = \frac{-\Delta H}{R}\left(\frac{1}{T_1}-\frac{1}{T_2}\right) $$
#
# Tip: Your high-school knowledge on Le Chatlier’s principle should apply directly to the equilibrium state of a reaction

# %% [markdown]
# Make sure you understand the following curves. Note the difference between rate and equilibrium:
#
# ![Reversible reactions 3.png](data:image/png;base64,...)
#
# ![Reversible reactions 4.png](data:image/png;base64,...)
#
# ![Reversible reactions 5.png](data:image/png;base64,...)
